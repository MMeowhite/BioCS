# %% [markdown]
# # Data Preparation

# %% [markdown]
# Creating a new dataset and save it as `.csv` file

# %%
import os

# %%
from google.colab import drive
import os

# 挂载 Google Drive
drive.mount('/content/drive')

# 设定数据文件路径（确保包含 My Drive）
base_path = "/content/drive/My Drive/Laboratory_Course/DeepLearning/data"
os.makedirs(base_path, exist_ok=True)  # 确保目录存在

data_file = os.path.join(base_path, 'house_tiny.csv')

# 写入数据
with open(data_file, 'w') as f:
    f.write("NuRooms,Alley,Price\n")
    f.write("NA,Pave,127500\n")
    f.write("2,NA,106000\n")
    f.write("4,NA,178100\n")
    f.write("NA,NA,140000\n")

print(f"file is saved to: {data_file}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# file is saved to: /content/drive/My Drive/Laboratory_Course/DeepLearning/data/house_tiny.csv

# %%
import pandas as pd

data = pd.read_csv(data_file)
data
# Out:
#    NuRooms Alley   Price
# 0      NaN  Pave  127500
# 1      2.0   NaN  106000
# 2      4.0   NaN  178100
# 3      NaN   NaN  140000

# %% [markdown]
# To deal with `NaN` value, there are several methods to solve it.
#
# - **Insert**
# - **Delete**

# %%
inputs, outputs = data.iloc[:, 0:2], data.iloc[:, 2]
inputs = inputs.fillna(inputs.mean(numeric_only=True))
inputs
# Out:
#    NuRooms Alley
# 0      3.0  Pave
# 1      2.0   NaN
# 2      4.0   NaN
# 3      3.0   NaN

# %%
inputs = pd.get_dummies(inputs, dummy_na=True, dtype=int)
inputs
# Out:
#    NuRooms  Alley_Pave  Alley_nan
# 0      3.0           1          0
# 1      2.0           0          1
# 2      4.0           0          1
# 3      3.0           0          1

# %%
import torch

X, y = torch.tensor(inputs.values), torch.tensor(outputs.values)
X, y
# Out:
# (tensor([[3., 1., 0.],
#          [2., 0., 1.],
#          [4., 0., 1.],
#          [3., 0., 1.]], dtype=torch.float64),
#  tensor([127500, 106000, 178100, 140000]))
